# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install tensorflow Pillow Mat4py matplotlib scikit-learn Numpy PyWavelets torch --quiet

# %%
import os
import PIL.Image
from mat4py import loadmat
import PIL
import matplotlib.pyplot as plt
from sklearn import covariance
import sklearn
import numpy as np
import pywt
import statistics
import torch
import tensorflow as tf

# %%
from mswavelet import MSWavelet
from main import Main

# %%
#print("Torch GPU: ", torch.cuda.get_device_name(0))
#print("Tensorflow GPU: ", tf.config.list_physical_devices('GPU'))

rootdir = "/content/gdrive/My Drive/Research Methods - Arban Uka/PreprocessedV2"
print("Rootdir", "exists: \""+rootdir+"\"" if os.path.exists(path=rootdir) else "does not exist.")
# Out:
# Rootdir exists: "/content/gdrive/My Drive/Research Methods - Arban Uka/PreprocessedV2"

# %%
main = Main(rootdir=rootdir)
main.pop_arrays_simple()
# Out:
# MSWavelet arrays:
# Number of MRI scans:  1849
# Number of unhealthy MRI scans:  677
# Number of healthy MRI scans:  1172
#
# CNNModel hyperparameters:
# Learning rate:  0.001
# Minibatch size:  1
# Epochs:  30
# Train/Test split:  0.8
#
# CNNModel arrays:
# self.filenames length:  1849
# self.unhealthyfilenames length:  677
# self.healthyfilenames length:  1172

# %%
main.build_model_SqueezeNet()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv1 (Conv2D)                 (None, 256, 256, 8)  1184        ['input_1[0][0]']
#
#  maxpool1 (MaxPooling2D)        (None, 84, 84, 8)    0           ['conv1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 84, 84, 8)   32          ['maxpool1[0][0]']
#  alization)
#
#  squeeze_fire2 (Conv2D)         (None, 84, 84, 4)    36          ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 84, 84, 4)   16          ['squeeze_fire2[0][0]']
#  rmalization)
#
#  expand1_fire2 (Conv2D)         (None, 84, 84, 4)    20          ['batch_normalization_1[0][0]']
#
#  expand2_fire2 (Conv2D)         (None, 84, 84, 4)    148         ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 84, 84, 4)   16          ['expand1_fire2[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 84, 84, 4)   16          ['expand2_fire2[0][0]']
#  rmalization)
#
#  merge2 (Concatenate)           (None, 84, 84, 8)    0           ['batch_normalization_2[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  squeeze_fire3 (Conv2D)         (None, 84, 84, 4)    36          ['merge2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 84, 84, 4)   16          ['squeeze_fire3[0][0]']
#  rmalization)
#
#  expand1_fire3 (Conv2D)         (None, 84, 84, 4)    20          ['batch_normalization_4[0][0]']
#
#  expand2_fire3 (Conv2D)         (None, 84, 84, 4)    148         ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 84, 84, 4)   16          ['expand1_fire3[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 84, 84, 4)   16          ['expand2_fire3[0][0]']
#  rmalization)
#
#  merge3 (Concatenate)           (None, 84, 84, 8)    0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  skip_conn3 (Concatenate)       (None, 84, 84, 16)   0           ['merge3[0][0]',
#                                                                   'merge2[0][0]']
#
#  squeeze_fire4 (Conv2D)         (None, 84, 84, 4)    68          ['skip_conn3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 84, 84, 4)   16          ['squeeze_fire4[0][0]']
#  rmalization)
#
#  expand1_fire4 (Conv2D)         (None, 84, 84, 4)    20          ['batch_normalization_7[0][0]']
#
#  expand2_fire4 (Conv2D)         (None, 84, 84, 4)    148         ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 84, 84, 4)   16          ['expand1_fire4[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 84, 84, 4)   16          ['expand2_fire4[0][0]']
#  rmalization)
#
#  merge4 (Concatenate)           (None, 84, 84, 8)    0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  maxpool4 (MaxPooling2D)        (None, 27, 27, 8)    0           ['merge4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 27, 27, 8)   32          ['maxpool4[0][0]']
#  ormalization)
#
#  squeeze_fire5 (Conv2D)         (None, 27, 27, 4)    36          ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 27, 27, 4)   16          ['squeeze_fire5[0][0]']
#  ormalization)
#
#  expand1_fire5 (Conv2D)         (None, 27, 27, 4)    20          ['batch_normalization_11[0][0]']
#
#  expand2_fire5 (Conv2D)         (None, 27, 27, 4)    148         ['batch_normalization_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 27, 27, 4)   16          ['expand1_fire5[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 27, 27, 4)   16          ['expand2_fire5[0][0]']
#  ormalization)
#
#  merge5 (Concatenate)           (None, 27, 27, 8)    0           ['batch_normalization_12[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  skip_conn5 (Concatenate)       (None, 27, 27, 16)   0           ['merge5[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  squeeze_fire6 (Conv2D)         (None, 27, 27, 4)    68          ['skip_conn5[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 27, 27, 4)   16          ['squeeze_fire6[0][0]']
#  ormalization)
#
#  expand1_fire6 (Conv2D)         (None, 27, 27, 4)    20          ['batch_normalization_14[0][0]']
#
#  expand2_fire6 (Conv2D)         (None, 27, 27, 4)    148         ['batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 27, 27, 4)   16          ['expand1_fire6[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 27, 27, 4)   16          ['expand2_fire6[0][0]']
#  ormalization)
#
#  merge6 (Concatenate)           (None, 27, 27, 8)    0           ['batch_normalization_15[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  squeeze_fire7 (Conv2D)         (None, 27, 27, 4)    36          ['merge6[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 27, 27, 4)   16          ['squeeze_fire7[0][0]']
#  ormalization)
#
#  expand1_fire7 (Conv2D)         (None, 27, 27, 4)    20          ['batch_normalization_17[0][0]']
#
#  expand2_fire7 (Conv2D)         (None, 27, 27, 4)    148         ['batch_normalization_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 27, 27, 4)   16          ['expand1_fire7[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 27, 27, 4)   16          ['expand2_fire7[0][0]']
#  ormalization)
#
#  merge7 (Concatenate)           (None, 27, 27, 8)    0           ['batch_normalization_18[0][0]',
#                                                                   'batch_normalization_19[0][0]']
#
#  skip_conn7 (Concatenate)       (None, 27, 27, 16)   0           ['merge7[0][0]',
#                                                                   'merge6[0][0]']
#
#  squeeze_fire8 (Conv2D)         (None, 27, 27, 4)    68          ['skip_conn7[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 27, 27, 4)   16          ['squeeze_fire8[0][0]']
#  ormalization)
#
#  expand1_fire8 (Conv2D)         (None, 27, 27, 4)    20          ['batch_normalization_20[0][0]']
#
#  expand2_fire8 (Conv2D)         (None, 27, 27, 4)    148         ['batch_normalization_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 27, 27, 4)   16          ['expand1_fire8[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 27, 27, 4)   16          ['expand2_fire8[0][0]']
#  ormalization)
#
#  merge8 (Concatenate)           (None, 27, 27, 8)    0           ['batch_normalization_21[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  maxpool8 (MaxPooling2D)        (None, 8, 8, 8)      0           ['merge8[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 8)     32          ['maxpool8[0][0]']
#  ormalization)
#
#  squeeze_fire9 (Conv2D)         (None, 8, 8, 4)      36          ['batch_normalization_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 4)     16          ['squeeze_fire9[0][0]']
#  ormalization)
#
#  expand1_fire9 (Conv2D)         (None, 8, 8, 4)      20          ['batch_normalization_24[0][0]']
#
#  expand2_fire9 (Conv2D)         (None, 8, 8, 4)      148         ['batch_normalization_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 8, 8, 4)     16          ['expand1_fire9[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 4)     16          ['expand2_fire9[0][0]']
#  ormalization)
#
#  merge9 (Concatenate)           (None, 8, 8, 8)      0           ['batch_normalization_25[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  skip_conn9 (Concatenate)       (None, 8, 8, 16)     0           ['merge9[0][0]',
#                                                                   'batch_normalization_23[0][0]']
#
#  conv_last (Conv2D)             (None, 8, 8, 1)      17          ['skip_conn9[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 1)     4           ['conv_last[0][0]']
#  ormalization)
#
#  flatten (Flatten)              (None, 64)           0           ['batch_normalization_27[0][0]']
#
#  dense (Dense)                  (None, 48)           3120        ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 48)           0           ['dense[0][0]']
#
#  dense2 (Dense)                 (None, 16)           784         ['dropout[0][0]']
#
#  sigmoid (Dense)                (None, 1)            17          ['dense2[0][0]']
#
# ==================================================================================================
# Total params: 7,334
# Trainable params: 7,092
# Non-trainable params: 242
# __________________________________________________________________________________________________

# %%
main.train_model(augment=True)
# Out:
# Found 1479 non-validated image filenames belonging to 2 classes.
# Found 370 non-validated image filenames belonging to 2 classes.
# Epoch 1/30
# 1479/1479 [==============================] - 115s 74ms/step - loss: 0.6707 - accuracy: 0.5950 - mse: 0.2386 - mae: 0.4636 - val_loss: 0.6376 - val_accuracy: 0.6432 - val_mse: 0.2242 - val_mae: 0.4502
# Epoch 2/30
# 1479/1479 [==============================] - 109s 74ms/step - loss: 0.6135 - accuracy: 0.6667 - mse: 0.2123 - mae: 0.4221 - val_loss: 0.5875 - val_accuracy: 0.7081 - val_mse: 0.1995 - val_mae: 0.3861
# Epoch 3/30
# 1479/1479 [==============================] - 110s 74ms/step - loss: 0.5741 - accuracy: 0.6897 - mse: 0.1965 - mae: 0.3894 - val_loss: 0.5042 - val_accuracy: 0.7595 - val_mse: 0.1651 - val_mae: 0.3397
# Epoch 4/30
# 1479/1479 [==============================] - 109s 73ms/step - loss: 0.5397 - accuracy: 0.7282 - mse: 0.1818 - mae: 0.3621 - val_loss: 0.4944 - val_accuracy: 0.7703 - val_mse: 0.1611 - val_mae: 0.3368
# Epoch 5/30
# 1479/1479 [==============================] - 109s 73ms/step - loss: 0.5266 - accuracy: 0.7329 - mse: 0.1765 - mae: 0.3493 - val_loss: 0.4854 - val_accuracy: 0.7730 - val_mse: 0.1588 - val_mae: 0.3372
# Epoch 6/30
# 1479/1479 [==============================] - 109s 74ms/step - loss: 0.5259 - accuracy: 0.7424 - mse: 0.1763 - mae: 0.3472 - val_loss: 0.4826 - val_accuracy: 0.7568 - val_mse: 0.1592 - val_mae: 0.3317
# Epoch 7/30
# 1479/1479 [==============================] - 109s 74ms/step - loss: 0.5086 - accuracy: 0.7566 - mse: 0.1681 - mae: 0.3379 - val_loss: 0.4583 - val_accuracy: 0.7865 - val_mse: 0.1470 - val_mae: 0.2982
# Epoch 8/30
# 1479/1479 [==============================] - 109s 73ms/step - loss: 0.5010 - accuracy: 0.7681 - mse: 0.1640 - mae: 0.3240 - val_loss: 0.4945 - val_accuracy: 0.7703 - val_mse: 0.1649 - val_mae: 0.3390
# Epoch 9/30
# 1479/1479 [==============================] - 109s 74ms/step - loss: 0.5060 - accuracy: 0.7525 - mse: 0.1672 - mae: 0.3335 - val_loss: 0.4740 - val_accuracy: 0.7919 - val_mse: 0.1549 - val_mae: 0.3201
# Epoch 10/30
# 1479/1479 [==============================] - 108s 73ms/step - loss: 0.4792 - accuracy: 0.7748 - mse: 0.1567 - mae: 0.3136 - val_loss: 0.4795 - val_accuracy: 0.7892 - val_mse: 0.1547 - val_mae: 0.3252
# Epoch 11/30
# 1479/1479 [==============================] - 110s 74ms/step - loss: 0.4727 - accuracy: 0.7823 - mse: 0.1536 - mae: 0.3049 - val_loss: 0.4544 - val_accuracy: 0.7919 - val_mse: 0.1477 - val_mae: 0.2964
# Epoch 12/30
# 1479/1479 [==============================] - 109s 74ms/step - loss: 0.4812 - accuracy: 0.7748 - mse: 0.1574 - mae: 0.3138 - val_loss: 0.5025 - val_accuracy: 0.7541 - val_mse: 0.1663 - val_mae: 0.3037
# Epoch 13/30
# 1479/1479 [==============================] - 110s 74ms/step - loss: 0.4763 - accuracy: 0.7863 - mse: 0.1540 - mae: 0.3060 - val_loss: 0.4476 - val_accuracy: 0.7973 - val_mse: 0.1448 - val_mae: 0.2924
# Epoch 14/30
# 1479/1479 [==============================] - 110s 74ms/step - loss: 0.4648 - accuracy: 0.7884 - mse: 0.1502 - mae: 0.2988 - val_loss: 0.4555 - val_accuracy: 0.7892 - val_mse: 0.1469 - val_mae: 0.3176
# Epoch 15/30
# 1479/1479 [==============================] - 109s 74ms/step - loss: 0.4637 - accuracy: 0.7890 - mse: 0.1511 - mae: 0.3046 - val_loss: 0.4935 - val_accuracy: 0.7703 - val_mse: 0.1622 - val_mae: 0.3045
# Epoch 16/30
# 1479/1479 [==============================] - 110s 75ms/step - loss: 0.4569 - accuracy: 0.7992 - mse: 0.1481 - mae: 0.2956 - val_loss: 0.4536 - val_accuracy: 0.7676 - val_mse: 0.1489 - val_mae: 0.2803
# Epoch 17/30
# 1479/1479 [==============================] - 110s 74ms/step - loss: 0.4682 - accuracy: 0.7884 - mse: 0.1515 - mae: 0.3008 - val_loss: 0.4783 - val_accuracy: 0.7838 - val_mse: 0.1565 - val_mae: 0.3319
# Epoch 18/30
# 1479/1479 [==============================] - 110s 75ms/step - loss: 0.4544 - accuracy: 0.7911 - mse: 0.1473 - mae: 0.2927 - val_loss: 0.4573 - val_accuracy: 0.7811 - val_mse: 0.1496 - val_mae: 0.3143
# Epoch 19/30
# 1479/1479 [==============================] - 110s 74ms/step - loss: 0.4516 - accuracy: 0.7843 - mse: 0.1464 - mae: 0.2946 - val_loss: 0.4745 - val_accuracy: 0.7649 - val_mse: 0.1582 - val_mae: 0.3227
# Epoch 20/30
# 1479/1479 [==============================] - 109s 74ms/step - loss: 0.4557 - accuracy: 0.7985 - mse: 0.1469 - mae: 0.2936 - val_loss: 0.5008 - val_accuracy: 0.7757 - val_mse: 0.1657 - val_mae: 0.3267
# Epoch 21/30
# 1479/1479 [==============================] - 110s 74ms/step - loss: 0.4512 - accuracy: 0.7951 - mse: 0.1446 - mae: 0.2919 - val_loss: 0.4553 - val_accuracy: 0.7811 - val_mse: 0.1490 - val_mae: 0.2812
# Epoch 22/30
# 1479/1479 [==============================] - 110s 75ms/step - loss: 0.4560 - accuracy: 0.7999 - mse: 0.1465 - mae: 0.2922 - val_loss: 0.4895 - val_accuracy: 0.7973 - val_mse: 0.1514 - val_mae: 0.2676
# Epoch 23/30
# 1479/1479 [==============================] - 110s 75ms/step - loss: 0.4571 - accuracy: 0.7863 - mse: 0.1476 - mae: 0.2932 - val_loss: 0.4558 - val_accuracy: 0.8081 - val_mse: 0.1453 - val_mae: 0.2903
# Epoch 24/30
# 1479/1479 [==============================] - 109s 73ms/step - loss: 0.4499 - accuracy: 0.7992 - mse: 0.1439 - mae: 0.2891 - val_loss: 0.4847 - val_accuracy: 0.7865 - val_mse: 0.1564 - val_mae: 0.3145
# Epoch 25/30
# 1479/1479 [==============================] - 109s 74ms/step - loss: 0.4357 - accuracy: 0.7965 - mse: 0.1398 - mae: 0.2810 - val_loss: 0.4974 - val_accuracy: 0.7784 - val_mse: 0.1631 - val_mae: 0.3228
# Epoch 26/30
# 1479/1479 [==============================] - 109s 74ms/step - loss: 0.4370 - accuracy: 0.8093 - mse: 0.1402 - mae: 0.2801 - val_loss: 0.4721 - val_accuracy: 0.8027 - val_mse: 0.1501 - val_mae: 0.2862
# Epoch 27/30
# 1479/1479 [==============================] - 110s 74ms/step - loss: 0.4357 - accuracy: 0.7958 - mse: 0.1413 - mae: 0.2779 - val_loss: 0.4539 - val_accuracy: 0.8189 - val_mse: 0.1450 - val_mae: 0.2984
# Epoch 28/30
# 1479/1479 [==============================] - 110s 74ms/step - loss: 0.4334 - accuracy: 0.8147 - mse: 0.1374 - mae: 0.2762 - val_loss: 0.4668 - val_accuracy: 0.7919 - val_mse: 0.1483 - val_mae: 0.2798
# Epoch 29/30
# 1479/1479 [==============================] - 110s 74ms/step - loss: 0.4473 - accuracy: 0.7992 - mse: 0.1446 - mae: 0.2892 - val_loss: 0.4500 - val_accuracy: 0.8081 - val_mse: 0.1461 - val_mae: 0.2814
# Epoch 30/30
# 1479/1479 [==============================] - 109s 74ms/step - loss: 0.4400 - accuracy: 0.8026 - mse: 0.1408 - mae: 0.2798 - val_loss: 0.4564 - val_accuracy: 0.7946 - val_mse: 0.1457 - val_mae: 0.2905

# %%
main.test_model()
# Out:
# Found 370 non-validated image filenames belonging to 2 classes.
# 370/370 [==============================] - 6s 15ms/step - loss: 0.4539 - accuracy: 0.8189 - mse: 0.1450 - mae: 0.2984
# 370/370 [==============================] - 6s 13ms/step
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       235
#            1       0.77      0.73      0.75       135
#
#     accuracy                           0.82       370
#    macro avg       0.81      0.80      0.80       370
# weighted avg       0.82      0.82      0.82       370

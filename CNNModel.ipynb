# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install tensorflow Pillow Mat4py matplotlib scikit-learn Numpy PyWavelets torch --quiet

# %%
import os
import PIL.Image
from mat4py import loadmat
import PIL
import matplotlib.pyplot as plt
from sklearn import covariance
import sklearn
import numpy as np
import pywt
import statistics
import torch
import tensorflow as tf

# %%
from mswavelet import MSWavelet
from cnnmodel import CNNModel

# %%
#print("Torch GPU: ", torch.cuda.get_device_name(0))
#print("Tensorflow GPU: ", tf.config.list_physical_devices('GPU'))

rootdir = "/content/gdrive/My Drive/Research Methods - Arban Uka/Preprocessed"
print("Rootdir", "exists: \""+rootdir+"\"" if os.path.exists(path=rootdir) else "does not exist.")
# Out:
# Rootdir exists: "/content/gdrive/My Drive/Research Methods - Arban Uka/Preprocessed"

# %%
cnnmodel = CNNModel(rootdir=rootdir)
cnnmodel.pop_arrays_simple()
# Out:
# MSWavelet arrays:
# Number of MRI scans:  1849
# Number of unhealthy MRI scans:  677
# Number of healthy MRI scans:  1172
#
# CNNModel hyperparameters:
# Learning rate:  0.001
# Minibatch size:  1
# Epochs:  25
# Train/Test split:  0.8
#
# CNNModel arrays:
# self.filenames length:  1849
# self.unhealthyfilenames length:  677
# self.healthyfilenames length:  1172

# %%
cnnmodel.build_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 501, 501, 4)       1732
#
#  max_pooling2d (MaxPooling2D  (None, 250, 250, 4)      0
#  )
#
#  spatial_dropout2d (SpatialD  (None, 250, 250, 4)      0
#  ropout2D)
#
#  batch_normalization (BatchN  (None, 250, 250, 4)      16
#  ormalization)
#
#  batch_normalization_1 (Batc  (None, 250, 250, 4)      16
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 247, 247, 8)       520
#
#  max_pooling2d_1 (MaxPooling  (None, 123, 123, 8)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 123, 123, 8)      32
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 120, 120, 4)       516
#
#  max_pooling2d_2 (MaxPooling  (None, 60, 60, 4)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 60, 60, 4)        16
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 57, 57, 2)         130
#
#  max_pooling2d_3 (MaxPooling  (None, 28, 28, 2)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 28, 28, 2)        8
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 1)         33
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 1)        0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 12, 12, 1)        4
#  hNormalization)
#
#  flatten (Flatten)           (None, 144)               0
#
#  dense (Dense)               (None, 32)                4640
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 8,336
# Trainable params: 8,290
# Non-trainable params: 46
# _________________________________________________________________

# %%
cnnmodel.train_model()
# Out:
# Found 1479 non-validated image filenames belonging to 2 classes.
# Found 370 non-validated image filenames belonging to 2 classes.
# Epoch 1/25
# 1479/1479 [==============================] - 593s 399ms/step - loss: 0.6072 - accuracy: 0.6755 - mse: 0.2096 - mae: 0.4155 - val_loss: 0.7480 - val_accuracy: 0.6703 - val_mse: 0.2129 - val_mae: 0.3280
# Epoch 2/25
# 1479/1479 [==============================] - 99s 67ms/step - loss: 0.5547 - accuracy: 0.7228 - mse: 0.1871 - mae: 0.3726 - val_loss: 0.4852 - val_accuracy: 0.7568 - val_mse: 0.1626 - val_mae: 0.3408
# Epoch 3/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.5155 - accuracy: 0.7485 - mse: 0.1707 - mae: 0.3393 - val_loss: 0.5340 - val_accuracy: 0.7378 - val_mse: 0.1743 - val_mae: 0.3391
# Epoch 4/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.4915 - accuracy: 0.7823 - mse: 0.1605 - mae: 0.3173 - val_loss: 0.5161 - val_accuracy: 0.7649 - val_mse: 0.1648 - val_mae: 0.2810
# Epoch 5/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.4822 - accuracy: 0.7728 - mse: 0.1588 - mae: 0.3193 - val_loss: 0.4918 - val_accuracy: 0.7595 - val_mse: 0.1642 - val_mae: 0.3445
# Epoch 6/25
# 1479/1479 [==============================] - 97s 66ms/step - loss: 0.4614 - accuracy: 0.7803 - mse: 0.1516 - mae: 0.3002 - val_loss: 0.4305 - val_accuracy: 0.8135 - val_mse: 0.1413 - val_mae: 0.2794
# Epoch 7/25
# 1479/1479 [==============================] - 97s 66ms/step - loss: 0.4465 - accuracy: 0.8053 - mse: 0.1440 - mae: 0.2889 - val_loss: 0.5018 - val_accuracy: 0.7757 - val_mse: 0.1635 - val_mae: 0.2676
# Epoch 8/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.4487 - accuracy: 0.7958 - mse: 0.1457 - mae: 0.2890 - val_loss: 0.4234 - val_accuracy: 0.8027 - val_mse: 0.1390 - val_mae: 0.2593
# Epoch 9/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.4346 - accuracy: 0.8012 - mse: 0.1401 - mae: 0.2803 - val_loss: 0.4468 - val_accuracy: 0.7919 - val_mse: 0.1471 - val_mae: 0.2534
# Epoch 10/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.4154 - accuracy: 0.7978 - mse: 0.1352 - mae: 0.2694 - val_loss: 0.4618 - val_accuracy: 0.7676 - val_mse: 0.1530 - val_mae: 0.2853
# Epoch 11/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.4254 - accuracy: 0.8026 - mse: 0.1366 - mae: 0.2733 - val_loss: 0.4243 - val_accuracy: 0.8027 - val_mse: 0.1367 - val_mae: 0.2703
# Epoch 12/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.4015 - accuracy: 0.8195 - mse: 0.1302 - mae: 0.2581 - val_loss: 0.4397 - val_accuracy: 0.7892 - val_mse: 0.1446 - val_mae: 0.2857
# Epoch 13/25
# 1479/1479 [==============================] - 99s 67ms/step - loss: 0.3859 - accuracy: 0.8303 - mse: 0.1237 - mae: 0.2517 - val_loss: 0.4455 - val_accuracy: 0.8135 - val_mse: 0.1392 - val_mae: 0.2276
# Epoch 14/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.3849 - accuracy: 0.8215 - mse: 0.1242 - mae: 0.2481 - val_loss: 0.4127 - val_accuracy: 0.8297 - val_mse: 0.1319 - val_mae: 0.2351
# Epoch 15/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.3818 - accuracy: 0.8289 - mse: 0.1222 - mae: 0.2443 - val_loss: 0.4720 - val_accuracy: 0.8000 - val_mse: 0.1426 - val_mae: 0.2314
# Epoch 16/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.3638 - accuracy: 0.8404 - mse: 0.1163 - mae: 0.2343 - val_loss: 0.4705 - val_accuracy: 0.8081 - val_mse: 0.1467 - val_mae: 0.2435
# Epoch 17/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.3695 - accuracy: 0.8404 - mse: 0.1174 - mae: 0.2343 - val_loss: 0.4449 - val_accuracy: 0.8081 - val_mse: 0.1387 - val_mae: 0.2287
# Epoch 18/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.3553 - accuracy: 0.8384 - mse: 0.1141 - mae: 0.2264 - val_loss: 0.4188 - val_accuracy: 0.8189 - val_mse: 0.1303 - val_mae: 0.2285
# Epoch 19/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.3465 - accuracy: 0.8411 - mse: 0.1109 - mae: 0.2251 - val_loss: 0.4749 - val_accuracy: 0.7946 - val_mse: 0.1481 - val_mae: 0.2637
# Epoch 20/25
# 1479/1479 [==============================] - 97s 66ms/step - loss: 0.3416 - accuracy: 0.8398 - mse: 0.1099 - mae: 0.2196 - val_loss: 0.5624 - val_accuracy: 0.8108 - val_mse: 0.1480 - val_mae: 0.2152
# Epoch 21/25
# 1479/1479 [==============================] - 97s 66ms/step - loss: 0.3197 - accuracy: 0.8560 - mse: 0.1015 - mae: 0.2018 - val_loss: 0.5297 - val_accuracy: 0.8135 - val_mse: 0.1444 - val_mae: 0.2206
# Epoch 22/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.3306 - accuracy: 0.8452 - mse: 0.1052 - mae: 0.2115 - val_loss: 0.5037 - val_accuracy: 0.8216 - val_mse: 0.1394 - val_mae: 0.2174
# Epoch 23/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.3128 - accuracy: 0.8594 - mse: 0.0997 - mae: 0.1978 - val_loss: 0.4371 - val_accuracy: 0.8351 - val_mse: 0.1271 - val_mae: 0.2133
# Epoch 24/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.3208 - accuracy: 0.8580 - mse: 0.1018 - mae: 0.2041 - val_loss: 0.4930 - val_accuracy: 0.8189 - val_mse: 0.1392 - val_mae: 0.2115
# Epoch 25/25
# 1479/1479 [==============================] - 98s 66ms/step - loss: 0.3109 - accuracy: 0.8560 - mse: 0.0986 - mae: 0.1986 - val_loss: 0.4892 - val_accuracy: 0.7865 - val_mse: 0.1517 - val_mae: 0.2597
#
#
# Training finished! Model saved at "model.h5".

# %%
cnnmodel.test_model()
# Out:
# Found 370 non-validated image filenames belonging to 2 classes.
# 370/370 [==============================] - 3s 9ms/step
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       235
#            1       0.69      0.74      0.72       135
#
#     accuracy                           0.79       370
#    macro avg       0.77      0.78      0.77       370
# weighted avg       0.79      0.79      0.79       370

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install tensorflow Pillow Mat4py matplotlib scikit-learn Numpy PyWavelets torch --quiet

# %%
import os
import PIL.Image
from mat4py import loadmat
import PIL
import matplotlib.pyplot as plt
from sklearn import covariance
import sklearn
import numpy as np
import pywt
import statistics
import torch
import tensorflow as tf

# %%
from mswavelet import MSWavelet
from cnnmodel import CNNModel

# %%
#print("Torch GPU: ", torch.cuda.get_device_name(0))
#print("Tensorflow GPU: ", tf.config.list_physical_devices('GPU'))

rootdir = "/content/gdrive/My Drive/Research Methods - Arban Uka/Preprocessed"
print("Rootdir", "exists: \""+rootdir+"\"" if os.path.exists(path=rootdir) else "does not exist.")
# Out:
# Rootdir exists: "/content/gdrive/My Drive/Research Methods - Arban Uka/Preprocessed"

# %%
cnnmodel = CNNModel(rootdir=rootdir)
cnnmodel.pop_arrays_simple()
# Out:
# MSWavelet arrays:
# Number of MRI scans:  1849
# Number of unhealthy MRI scans:  677
# Number of healthy MRI scans:  1172
#
# CNNModel hyperparameters:
# Learning rate:  0.001
# Minibatch size:  2
# Epochs:  30
# Train/Test split:  0.8
#
# CNNModel arrays:
# self.filenames length:  1849
# self.unhealthyfilenames length:  677
# self.healthyfilenames length:  1172

# %%
cnnmodel.build_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 501, 501, 4)       1732
#
#  max_pooling2d (MaxPooling2D  (None, 250, 250, 4)      0
#  )
#
#  spatial_dropout2d (SpatialD  (None, 250, 250, 4)      0
#  ropout2D)
#
#  batch_normalization (BatchN  (None, 250, 250, 4)      16
#  ormalization)
#
#  batch_normalization_1 (Batc  (None, 250, 250, 4)      16
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 247, 247, 8)       520
#
#  max_pooling2d_1 (MaxPooling  (None, 123, 123, 8)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 123, 123, 8)      32
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 120, 120, 4)       516
#
#  max_pooling2d_2 (MaxPooling  (None, 60, 60, 4)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 60, 60, 4)        16
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 57, 57, 2)         130
#
#  max_pooling2d_3 (MaxPooling  (None, 28, 28, 2)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 28, 28, 2)        8
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 1)         33
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 1)        0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 12, 12, 1)        4
#  hNormalization)
#
#  flatten (Flatten)           (None, 144)               0
#
#  dense (Dense)               (None, 32)                4640
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 8,336
# Trainable params: 8,290
# Non-trainable params: 46
# _________________________________________________________________

# %%
cnnmodel.train_model()
# Out:
# Found 1479 non-validated image filenames belonging to 2 classes.
# Found 370 non-validated image filenames belonging to 2 classes.
# Epoch 1/30
# 740/740 [==============================] - 541s 716ms/step - loss: 0.5759 - accuracy: 0.6856 - mse: 0.1972 - mae: 0.3954 - val_loss: 0.4853 - val_accuracy: 0.7676 - val_mse: 0.1588 - val_mae: 0.3378
# Epoch 2/30
# 740/740 [==============================] - 94s 127ms/step - loss: 0.5251 - accuracy: 0.7593 - mse: 0.1728 - mae: 0.3438 - val_loss: 0.4795 - val_accuracy: 0.7730 - val_mse: 0.1561 - val_mae: 0.2991
# Epoch 3/30
# 740/740 [==============================] - 93s 126ms/step - loss: 0.5044 - accuracy: 0.7708 - mse: 0.1646 - mae: 0.3281 - val_loss: 0.4643 - val_accuracy: 0.7757 - val_mse: 0.1519 - val_mae: 0.2903
# Epoch 4/30
# 740/740 [==============================] - 92s 125ms/step - loss: 0.4835 - accuracy: 0.7904 - mse: 0.1558 - mae: 0.3121 - val_loss: 0.4778 - val_accuracy: 0.7784 - val_mse: 0.1549 - val_mae: 0.3171
# Epoch 5/30
# 740/740 [==============================] - 93s 125ms/step - loss: 0.4806 - accuracy: 0.7830 - mse: 0.1551 - mae: 0.3084 - val_loss: 0.4628 - val_accuracy: 0.7919 - val_mse: 0.1495 - val_mae: 0.3132
# Epoch 6/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4782 - accuracy: 0.7830 - mse: 0.1551 - mae: 0.3065 - val_loss: 0.5044 - val_accuracy: 0.7730 - val_mse: 0.1643 - val_mae: 0.3207
# Epoch 7/30
# 740/740 [==============================] - 93s 125ms/step - loss: 0.4696 - accuracy: 0.7789 - mse: 0.1534 - mae: 0.3053 - val_loss: 0.4723 - val_accuracy: 0.7865 - val_mse: 0.1529 - val_mae: 0.3140
# Epoch 8/30
# 740/740 [==============================] - 93s 125ms/step - loss: 0.4672 - accuracy: 0.7843 - mse: 0.1514 - mae: 0.3039 - val_loss: 0.4616 - val_accuracy: 0.7865 - val_mse: 0.1504 - val_mae: 0.2766
# Epoch 9/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4658 - accuracy: 0.7796 - mse: 0.1523 - mae: 0.3048 - val_loss: 0.4799 - val_accuracy: 0.7865 - val_mse: 0.1550 - val_mae: 0.2867
# Epoch 10/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4575 - accuracy: 0.7884 - mse: 0.1486 - mae: 0.2988 - val_loss: 0.4545 - val_accuracy: 0.7730 - val_mse: 0.1491 - val_mae: 0.2795
# Epoch 11/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4481 - accuracy: 0.8005 - mse: 0.1462 - mae: 0.2913 - val_loss: 0.4826 - val_accuracy: 0.7811 - val_mse: 0.1567 - val_mae: 0.3290
# Epoch 12/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4573 - accuracy: 0.7721 - mse: 0.1503 - mae: 0.3045 - val_loss: 0.4793 - val_accuracy: 0.7919 - val_mse: 0.1547 - val_mae: 0.2786
# Epoch 13/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4454 - accuracy: 0.7972 - mse: 0.1444 - mae: 0.2879 - val_loss: 0.4608 - val_accuracy: 0.7919 - val_mse: 0.1474 - val_mae: 0.2928
# Epoch 14/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4315 - accuracy: 0.7958 - mse: 0.1407 - mae: 0.2831 - val_loss: 0.4595 - val_accuracy: 0.7865 - val_mse: 0.1480 - val_mae: 0.2899
# Epoch 15/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4243 - accuracy: 0.7965 - mse: 0.1388 - mae: 0.2770 - val_loss: 0.4621 - val_accuracy: 0.7973 - val_mse: 0.1486 - val_mae: 0.2827
# Epoch 16/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4325 - accuracy: 0.7999 - mse: 0.1400 - mae: 0.2817 - val_loss: 0.4658 - val_accuracy: 0.7784 - val_mse: 0.1510 - val_mae: 0.2881
# Epoch 17/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4240 - accuracy: 0.8039 - mse: 0.1393 - mae: 0.2786 - val_loss: 0.4504 - val_accuracy: 0.7865 - val_mse: 0.1451 - val_mae: 0.2611
# Epoch 18/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4110 - accuracy: 0.8046 - mse: 0.1343 - mae: 0.2649 - val_loss: 0.4444 - val_accuracy: 0.8108 - val_mse: 0.1434 - val_mae: 0.2738
# Epoch 19/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4148 - accuracy: 0.7965 - mse: 0.1348 - mae: 0.2715 - val_loss: 0.4387 - val_accuracy: 0.7973 - val_mse: 0.1429 - val_mae: 0.2847
# Epoch 20/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.4053 - accuracy: 0.8080 - mse: 0.1312 - mae: 0.2670 - val_loss: 0.4474 - val_accuracy: 0.7973 - val_mse: 0.1437 - val_mae: 0.2510
# Epoch 21/30
# 740/740 [==============================] - 92s 125ms/step - loss: 0.4088 - accuracy: 0.8087 - mse: 0.1335 - mae: 0.2659 - val_loss: 0.4468 - val_accuracy: 0.8054 - val_mse: 0.1422 - val_mae: 0.2625
# Epoch 22/30
# 740/740 [==============================] - 92s 125ms/step - loss: 0.4056 - accuracy: 0.8127 - mse: 0.1319 - mae: 0.2648 - val_loss: 0.4522 - val_accuracy: 0.7892 - val_mse: 0.1454 - val_mae: 0.2932
# Epoch 23/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.3820 - accuracy: 0.8141 - mse: 0.1225 - mae: 0.2458 - val_loss: 0.4789 - val_accuracy: 0.7811 - val_mse: 0.1487 - val_mae: 0.2888
# Epoch 24/30
# 740/740 [==============================] - 91s 124ms/step - loss: 0.3966 - accuracy: 0.8127 - mse: 0.1288 - mae: 0.2575 - val_loss: 0.4581 - val_accuracy: 0.7919 - val_mse: 0.1497 - val_mae: 0.2715
# Epoch 25/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.3864 - accuracy: 0.8195 - mse: 0.1246 - mae: 0.2511 - val_loss: 0.4682 - val_accuracy: 0.7919 - val_mse: 0.1485 - val_mae: 0.2694
# Epoch 26/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.3774 - accuracy: 0.8235 - mse: 0.1222 - mae: 0.2460 - val_loss: 0.4899 - val_accuracy: 0.7946 - val_mse: 0.1498 - val_mae: 0.2481
# Epoch 27/30
# 740/740 [==============================] - 92s 125ms/step - loss: 0.3811 - accuracy: 0.8229 - mse: 0.1223 - mae: 0.2418 - val_loss: 0.5108 - val_accuracy: 0.7541 - val_mse: 0.1608 - val_mae: 0.3090
# Epoch 28/30
# 740/740 [==============================] - 92s 125ms/step - loss: 0.3772 - accuracy: 0.8222 - mse: 0.1208 - mae: 0.2439 - val_loss: 0.4680 - val_accuracy: 0.8000 - val_mse: 0.1490 - val_mae: 0.2645
# Epoch 29/30
# 740/740 [==============================] - 92s 125ms/step - loss: 0.3757 - accuracy: 0.8229 - mse: 0.1215 - mae: 0.2422 - val_loss: 0.4987 - val_accuracy: 0.7946 - val_mse: 0.1505 - val_mae: 0.2546
# Epoch 30/30
# 740/740 [==============================] - 92s 124ms/step - loss: 0.3516 - accuracy: 0.8256 - mse: 0.1142 - mae: 0.2306 - val_loss: 0.4639 - val_accuracy: 0.7919 - val_mse: 0.1466 - val_mae: 0.2641
#
#
# Training finished! Model saved at "model.h5".

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install tensorflow Pillow Mat4py matplotlib scikit-learn Numpy PyWavelets torch --quiet

# %%
import os
import PIL.Image
from mat4py import loadmat
import PIL
import matplotlib.pyplot as plt
from sklearn import covariance
import sklearn
import numpy as np
import pywt
import statistics
import torch
import tensorflow as tf

# %%
from mswavelet import MSWavelet
from cnnmodel import CNNModel

# %%
#print("Torch GPU: ", torch.cuda.get_device_name(0))
#print("Tensorflow GPU: ", tf.config.list_physical_devices('GPU'))

rootdir = "/content/gdrive/My Drive/Research Methods - Arban Uka/Preprocessed"
print("Rootdir", "exists: \""+rootdir+"\"" if os.path.exists(path=rootdir) else "does not exist.")
# Out:
# Rootdir exists: "/content/gdrive/My Drive/Research Methods - Arban Uka/Preprocessed"

# %%
cnnmodel = CNNModel(rootdir=rootdir)
cnnmodel.pop_arrays_simple()
# Out:
# MSWavelet arrays:
# Number of MRI scans:  1849
# Number of unhealthy MRI scans:  677
# Number of healthy MRI scans:  1172
#
# CNNModel hyperparameters:
# Learning rate:  0.001
# Minibatch size:  1
# Epochs:  25
# Train/Test split:  0.8
#
# CNNModel arrays:
# self.filenames length:  1849
# self.unhealthyfilenames length:  677
# self.healthyfilenames length:  1172

# %%
cnnmodel.build_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 501, 501, 4)       1732
#
#  max_pooling2d (MaxPooling2D  (None, 250, 250, 4)      0
#  )
#
#  spatial_dropout2d (SpatialD  (None, 250, 250, 4)      0
#  ropout2D)
#
#  batch_normalization (BatchN  (None, 250, 250, 4)      16
#  ormalization)
#
#  batch_normalization_1 (Batc  (None, 250, 250, 4)      16
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 247, 247, 8)       520
#
#  max_pooling2d_1 (MaxPooling  (None, 123, 123, 8)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 123, 123, 8)      32
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 120, 120, 4)       516
#
#  max_pooling2d_2 (MaxPooling  (None, 60, 60, 4)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 60, 60, 4)        16
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 57, 57, 2)         130
#
#  max_pooling2d_3 (MaxPooling  (None, 28, 28, 2)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 28, 28, 2)        8
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 1)         33
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 1)        0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 12, 12, 1)        4
#  hNormalization)
#
#  flatten (Flatten)           (None, 144)               0
#
#  dense (Dense)               (None, 32)                4640
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 8,336
# Trainable params: 8,290
# Non-trainable params: 46
# _________________________________________________________________

# %%
cnnmodel.train_model()
# Out:
# Found 1479 non-validated image filenames belonging to 2 classes.
# Found 370 non-validated image filenames belonging to 2 classes.
# Epoch 1/25
# 1479/1479 [==============================] - 116s 77ms/step - loss: 0.6082 - accuracy: 0.6640 - mse: 0.2103 - mae: 0.4149 - val_loss: 0.5065 - val_accuracy: 0.7432 - val_mse: 0.1698 - val_mae: 0.3463
# Epoch 2/25
# 1479/1479 [==============================] - 113s 77ms/step - loss: 0.5438 - accuracy: 0.7282 - mse: 0.1833 - mae: 0.3647 - val_loss: 0.4833 - val_accuracy: 0.7811 - val_mse: 0.1566 - val_mae: 0.3139
# Epoch 3/25
# 1479/1479 [==============================] - 113s 76ms/step - loss: 0.5065 - accuracy: 0.7634 - mse: 0.1669 - mae: 0.3310 - val_loss: 0.5062 - val_accuracy: 0.7514 - val_mse: 0.1650 - val_mae: 0.3193
# Epoch 4/25
# 1479/1479 [==============================] - 112s 76ms/step - loss: 0.4998 - accuracy: 0.7667 - mse: 0.1639 - mae: 0.3292 - val_loss: 0.5309 - val_accuracy: 0.7757 - val_mse: 0.1668 - val_mae: 0.2617
# Epoch 5/25
# 1479/1479 [==============================] - 112s 76ms/step - loss: 0.4972 - accuracy: 0.7600 - mse: 0.1634 - mae: 0.3271 - val_loss: 0.4936 - val_accuracy: 0.7865 - val_mse: 0.1548 - val_mae: 0.2603
# Epoch 6/25
# 1479/1479 [==============================] - 112s 76ms/step - loss: 0.4828 - accuracy: 0.7748 - mse: 0.1570 - mae: 0.3135 - val_loss: 0.4777 - val_accuracy: 0.7865 - val_mse: 0.1564 - val_mae: 0.3197
# Epoch 7/25
# 1479/1479 [==============================] - 111s 75ms/step - loss: 0.4709 - accuracy: 0.7857 - mse: 0.1527 - mae: 0.3059 - val_loss: 0.5340 - val_accuracy: 0.7595 - val_mse: 0.1670 - val_mae: 0.2684
# Epoch 8/25
# 1479/1479 [==============================] - 112s 76ms/step - loss: 0.4633 - accuracy: 0.7857 - mse: 0.1506 - mae: 0.3002 - val_loss: 0.5383 - val_accuracy: 0.7838 - val_mse: 0.1595 - val_mae: 0.2414
# Epoch 9/25
# 1479/1479 [==============================] - 112s 76ms/step - loss: 0.4509 - accuracy: 0.7863 - mse: 0.1467 - mae: 0.2939 - val_loss: 0.5029 - val_accuracy: 0.7892 - val_mse: 0.1523 - val_mae: 0.2439
# Epoch 10/25
# 1479/1479 [==============================] - 112s 76ms/step - loss: 0.4439 - accuracy: 0.7951 - mse: 0.1434 - mae: 0.2844 - val_loss: 0.4876 - val_accuracy: 0.8000 - val_mse: 0.1556 - val_mae: 0.2990
# Epoch 11/25
# 1479/1479 [==============================] - 112s 76ms/step - loss: 0.4353 - accuracy: 0.7945 - mse: 0.1416 - mae: 0.2820 - val_loss: 0.5406 - val_accuracy: 0.7811 - val_mse: 0.1648 - val_mae: 0.2942
# Epoch 12/25
# 1479/1479 [==============================] - 112s 76ms/step - loss: 0.4321 - accuracy: 0.7978 - mse: 0.1401 - mae: 0.2778 - val_loss: 0.4730 - val_accuracy: 0.8081 - val_mse: 0.1459 - val_mae: 0.2914
# Epoch 13/25
# 1479/1479 [==============================] - 111s 75ms/step - loss: 0.4214 - accuracy: 0.7965 - mse: 0.1368 - mae: 0.2730 - val_loss: 0.6735 - val_accuracy: 0.7757 - val_mse: 0.1712 - val_mae: 0.2412
# Epoch 14/25
# 1479/1479 [==============================] - 111s 75ms/step - loss: 0.4313 - accuracy: 0.8005 - mse: 0.1401 - mae: 0.2772 - val_loss: 0.5362 - val_accuracy: 0.7973 - val_mse: 0.1566 - val_mae: 0.2655
# Epoch 15/25
# 1479/1479 [==============================] - 112s 76ms/step - loss: 0.4128 - accuracy: 0.8087 - mse: 0.1340 - mae: 0.2679 - val_loss: 0.5970 - val_accuracy: 0.7919 - val_mse: 0.1616 - val_mae: 0.2368
# Epoch 16/25
# 1479/1479 [==============================] - 110s 74ms/step - loss: 0.4071 - accuracy: 0.8100 - mse: 0.1319 - mae: 0.2629 - val_loss: 0.4870 - val_accuracy: 0.8081 - val_mse: 0.1424 - val_mae: 0.2473
# Epoch 17/25
# 1479/1479 [==============================] - 111s 75ms/step - loss: 0.3903 - accuracy: 0.8087 - mse: 0.1276 - mae: 0.2524 - val_loss: 0.5486 - val_accuracy: 0.8081 - val_mse: 0.1479 - val_mae: 0.2330
# Epoch 18/25
# 1479/1479 [==============================] - 110s 75ms/step - loss: 0.3908 - accuracy: 0.8181 - mse: 0.1257 - mae: 0.2515 - val_loss: 0.6277 - val_accuracy: 0.7919 - val_mse: 0.1612 - val_mae: 0.2273
# Epoch 19/25
# 1479/1479 [==============================] - 114s 77ms/step - loss: 0.3804 - accuracy: 0.8222 - mse: 0.1226 - mae: 0.2427 - val_loss: 0.4855 - val_accuracy: 0.7703 - val_mse: 0.1549 - val_mae: 0.2914
# Epoch 20/25
# 1479/1479 [==============================] - 114s 77ms/step - loss: 0.3553 - accuracy: 0.8350 - mse: 0.1138 - mae: 0.2312 - val_loss: 0.5330 - val_accuracy: 0.7595 - val_mse: 0.1749 - val_mae: 0.3570
# Epoch 21/25
# 1479/1479 [==============================] - 116s 78ms/step - loss: 0.3600 - accuracy: 0.8371 - mse: 0.1148 - mae: 0.2279 - val_loss: 0.5580 - val_accuracy: 0.7838 - val_mse: 0.1546 - val_mae: 0.2621
# Epoch 22/25
# 1479/1479 [==============================] - 115s 78ms/step - loss: 0.3473 - accuracy: 0.8371 - mse: 0.1126 - mae: 0.2235 - val_loss: 0.5811 - val_accuracy: 0.7811 - val_mse: 0.1576 - val_mae: 0.2592
# Epoch 23/25
# 1479/1479 [==============================] - 115s 78ms/step - loss: 0.3485 - accuracy: 0.8343 - mse: 0.1122 - mae: 0.2238 - val_loss: 0.7024 - val_accuracy: 0.7946 - val_mse: 0.1657 - val_mae: 0.2327
# Epoch 24/25
# 1479/1479 [==============================] - 115s 78ms/step - loss: 0.3520 - accuracy: 0.8377 - mse: 0.1130 - mae: 0.2233 - val_loss: 0.5701 - val_accuracy: 0.7973 - val_mse: 0.1493 - val_mae: 0.2436
# Epoch 25/25
# 1479/1479 [==============================] - 115s 78ms/step - loss: 0.3498 - accuracy: 0.8303 - mse: 0.1129 - mae: 0.2238 - val_loss: 0.7606 - val_accuracy: 0.7946 - val_mse: 0.1631 - val_mae: 0.2235

# %%
cnnmodel.test_model()
# Out:
# Found 370 non-validated image filenames belonging to 2 classes.
# 370/370 [==============================] - 4s 11ms/step
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       235
#            1       0.75      0.71      0.73       135
#
#     accuracy                           0.81       370
#    macro avg       0.79      0.79      0.79       370
# weighted avg       0.81      0.81      0.81       370

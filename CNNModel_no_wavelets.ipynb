# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install tensorflow Pillow Mat4py matplotlib scikit-learn Numpy PyWavelets torch --quiet

# %%
import os
import PIL.Image
from mat4py import loadmat
import PIL
import matplotlib.pyplot as plt
from sklearn import covariance
import sklearn
import numpy as np
import pywt
import statistics
import torch
import tensorflow as tf

# %%
from mswavelet import MSWavelet
from cnnmodel import CNNModel

# %%
#print("Torch GPU: ", torch.cuda.get_device_name(0))
#print("Tensorflow GPU: ", tf.config.list_physical_devices('GPU'))

rootdir = "/content/gdrive/My Drive/Research Methods - Arban Uka/MRIFreeDataset"
print("Rootdir", "exists: \""+rootdir+"\"" if os.path.exists(path=rootdir) else "does not exist.")
# Out:
# Rootdir exists: "/content/gdrive/My Drive/Research Methods - Arban Uka/MRIFreeDataset"

# %%
cnnmodel = CNNModel(rootdir=rootdir)
cnnmodel.pop_arrays_simple()
# Out:
# MSWavelet arrays:
# Number of MRI scans:  1849
# Number of unhealthy MRI scans:  677
# Number of healthy MRI scans:  1172
#
# CNNModel hyperparameters:
# Learning rate:  0.001
# Minibatch size:  1
# Epochs:  25
# Train/Test split:  0.8
#
# CNNModel arrays:
# self.filenames length:  1849
# self.unhealthyfilenames length:  677
# self.healthyfilenames length:  1172

# %%
cnnmodel.build_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 501, 501, 4)       580
#
#  max_pooling2d (MaxPooling2D  (None, 250, 250, 4)      0
#  )
#
#  spatial_dropout2d (SpatialD  (None, 250, 250, 4)      0
#  ropout2D)
#
#  batch_normalization (BatchN  (None, 250, 250, 4)      16
#  ormalization)
#
#  batch_normalization_1 (Batc  (None, 250, 250, 4)      16
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 247, 247, 8)       520
#
#  max_pooling2d_1 (MaxPooling  (None, 123, 123, 8)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 123, 123, 8)      32
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 120, 120, 4)       516
#
#  max_pooling2d_2 (MaxPooling  (None, 60, 60, 4)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 60, 60, 4)        16
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 57, 57, 2)         130
#
#  max_pooling2d_3 (MaxPooling  (None, 28, 28, 2)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 28, 28, 2)        8
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 1)         33
#
#  max_pooling2d_4 (MaxPooling  (None, 12, 12, 1)        0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 12, 12, 1)        4
#  hNormalization)
#
#  flatten (Flatten)           (None, 144)               0
#
#  dense (Dense)               (None, 32)                4640
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 7,184
# Trainable params: 7,138
# Non-trainable params: 46
# _________________________________________________________________

# %%
cnnmodel.train_model()
# Out:
# Found 1479 non-validated image filenames belonging to 2 classes.
# Found 370 non-validated image filenames belonging to 2 classes.
# Epoch 1/25
# 1479/1479 [==============================] - 41s 26ms/step - loss: 0.5619 - accuracy: 0.7039 - mse: 0.1900 - mae: 0.3814 - val_loss: 0.6373 - val_accuracy: 0.5568 - val_mse: 0.2238 - val_mae: 0.4607
# Epoch 2/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.5250 - accuracy: 0.7458 - mse: 0.1752 - mae: 0.3480 - val_loss: 0.5167 - val_accuracy: 0.7514 - val_mse: 0.1709 - val_mae: 0.3708
# Epoch 3/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.5243 - accuracy: 0.7485 - mse: 0.1742 - mae: 0.3466 - val_loss: 0.5751 - val_accuracy: 0.6270 - val_mse: 0.1971 - val_mae: 0.3929
# Epoch 4/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.5012 - accuracy: 0.7688 - mse: 0.1655 - mae: 0.3258 - val_loss: 0.5331 - val_accuracy: 0.6811 - val_mse: 0.1816 - val_mae: 0.3709
# Epoch 5/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4908 - accuracy: 0.7708 - mse: 0.1609 - mae: 0.3204 - val_loss: 0.4947 - val_accuracy: 0.7676 - val_mse: 0.1619 - val_mae: 0.3446
# Epoch 6/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4785 - accuracy: 0.7863 - mse: 0.1561 - mae: 0.3146 - val_loss: 0.4757 - val_accuracy: 0.7649 - val_mse: 0.1566 - val_mae: 0.3033
# Epoch 7/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4565 - accuracy: 0.7985 - mse: 0.1471 - mae: 0.2937 - val_loss: 0.4890 - val_accuracy: 0.8054 - val_mse: 0.1588 - val_mae: 0.3504
# Epoch 8/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4646 - accuracy: 0.7843 - mse: 0.1500 - mae: 0.2979 - val_loss: 0.5459 - val_accuracy: 0.7730 - val_mse: 0.1671 - val_mae: 0.2724
# Epoch 9/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4448 - accuracy: 0.8019 - mse: 0.1416 - mae: 0.2860 - val_loss: 0.4692 - val_accuracy: 0.7919 - val_mse: 0.1489 - val_mae: 0.2870
# Epoch 10/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4312 - accuracy: 0.8141 - mse: 0.1364 - mae: 0.2729 - val_loss: 0.4793 - val_accuracy: 0.7703 - val_mse: 0.1572 - val_mae: 0.3314
# Epoch 11/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4390 - accuracy: 0.8073 - mse: 0.1393 - mae: 0.2750 - val_loss: 0.4601 - val_accuracy: 0.7973 - val_mse: 0.1483 - val_mae: 0.2852
# Epoch 12/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4184 - accuracy: 0.8066 - mse: 0.1334 - mae: 0.2693 - val_loss: 0.4734 - val_accuracy: 0.8054 - val_mse: 0.1453 - val_mae: 0.2662
# Epoch 13/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4181 - accuracy: 0.8053 - mse: 0.1344 - mae: 0.2679 - val_loss: 0.4621 - val_accuracy: 0.8081 - val_mse: 0.1449 - val_mae: 0.2891
# Epoch 14/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4201 - accuracy: 0.8181 - mse: 0.1333 - mae: 0.2663 - val_loss: 0.4827 - val_accuracy: 0.7973 - val_mse: 0.1508 - val_mae: 0.2911
# Epoch 15/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4047 - accuracy: 0.8174 - mse: 0.1283 - mae: 0.2561 - val_loss: 0.4856 - val_accuracy: 0.8054 - val_mse: 0.1499 - val_mae: 0.2708
# Epoch 16/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.4023 - accuracy: 0.8195 - mse: 0.1269 - mae: 0.2524 - val_loss: 0.5220 - val_accuracy: 0.8000 - val_mse: 0.1553 - val_mae: 0.2673
# Epoch 17/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.3833 - accuracy: 0.8330 - mse: 0.1206 - mae: 0.2444 - val_loss: 0.4893 - val_accuracy: 0.7486 - val_mse: 0.1589 - val_mae: 0.3244
# Epoch 18/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.3971 - accuracy: 0.8276 - mse: 0.1245 - mae: 0.2471 - val_loss: 0.4983 - val_accuracy: 0.7865 - val_mse: 0.1568 - val_mae: 0.2969
# Epoch 19/25
# 1479/1479 [==============================] - 39s 26ms/step - loss: 0.3782 - accuracy: 0.8364 - mse: 0.1187 - mae: 0.2440 - val_loss: 0.5275 - val_accuracy: 0.7730 - val_mse: 0.1615 - val_mae: 0.2875
# Epoch 20/25
# 1479/1479 [==============================] - 39s 26ms/step - loss: 0.3654 - accuracy: 0.8485 - mse: 0.1138 - mae: 0.2273 - val_loss: 0.5360 - val_accuracy: 0.7811 - val_mse: 0.1553 - val_mae: 0.2512
# Epoch 21/25
# 1479/1479 [==============================] - 39s 26ms/step - loss: 0.3677 - accuracy: 0.8391 - mse: 0.1143 - mae: 0.2278 - val_loss: 0.5338 - val_accuracy: 0.8027 - val_mse: 0.1560 - val_mae: 0.2756
# Epoch 22/25
# 1479/1479 [==============================] - 39s 26ms/step - loss: 0.3579 - accuracy: 0.8431 - mse: 0.1125 - mae: 0.2267 - val_loss: 0.5492 - val_accuracy: 0.8027 - val_mse: 0.1553 - val_mae: 0.2556
# Epoch 23/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.3543 - accuracy: 0.8553 - mse: 0.1089 - mae: 0.2176 - val_loss: 0.5940 - val_accuracy: 0.8000 - val_mse: 0.1591 - val_mae: 0.2465
# Epoch 24/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.3419 - accuracy: 0.8452 - mse: 0.1081 - mae: 0.2153 - val_loss: 0.5956 - val_accuracy: 0.8000 - val_mse: 0.1614 - val_mae: 0.2567
# Epoch 25/25
# 1479/1479 [==============================] - 38s 26ms/step - loss: 0.3460 - accuracy: 0.8445 - mse: 0.1089 - mae: 0.2192 - val_loss: 0.6855 - val_accuracy: 0.7865 - val_mse: 0.1675 - val_mae: 0.2435
#
#
# Training finished! Model saved at "model.h5".

# %%
cnnmodel.test_model()
# Out:
# Found 370 non-validated image filenames belonging to 2 classes.
# 370/370 [==============================] - 2s 5ms/step
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       235
#            1       0.74      0.64      0.69       135
#
#     accuracy                           0.79       370
#    macro avg       0.77      0.76      0.76       370
# weighted avg       0.78      0.79      0.78       370
